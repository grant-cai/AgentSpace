# %%
from Agent import personAgent
import json

# %%
agent = personAgent("essay_chunk_agentspace", "chunk_index")

# %%
# Load evaluation questions
with open("../Evaluation/test_questions.json", "r") as f:
    questions = json.load(f)

# %%
# Run evaluation loop for the first few questions
for item in questions[:3]:
    thread_id = agent.new_thread_id()
    question = item['question']
    print(f"--- Question ---\n{question}\n")
    
    response = agent.chat(question, thread_id)
    agent_response = response if response else "No response"
    
    print(f"--- Agent Response ---\n{agent_response}\n")
    print(f"--- Ground Truth ---\n{item['ground_truth']}\n")
    print("=" * 80 + "\n")
# Out:
# --- Question ---
# What are the four essential parts of a body paragraph as described in the text?
#
# --- Agent Response ---
# Hey, great question to start with! These are super important to know before diving into any essay. 😊
#
# So based on what we cover, the four essential parts of a body paragraph are:
#
# 1. **Topic Sentence** — This kicks off your paragraph! It connects the specific topic of your paragraph back to your thesis and lets your reader know a new part of your argument is starting.
#
# 2. **Evidence** — This is any detail, fact, quote, or example that helps illustrate your claim. The type of evidence you use will depend on what kind of paper you're writing!
#
# 3. **Analysis** — This is where *you* come in and explain *why* your evidence matters. Your reader can't read your mind, so you have to connect the dots for them and show how your evidence actually proves your thesis.
#
# 4. **Transitions** — These show how ideas within your paragraph (and between paragraphs!) relate to each other. They help your reader follow your organization and logic.
#
# ---
#
# Here's something worth thinking about though — **how do you feel about each of those four parts?** Are any of them clicking for you, or is there one that feels a little fuzzy? 🤔
#
# Sometimes students feel pretty confident about evidence but then struggle with analysis, for example. Where do *you* feel like you're at with these?
#
# --- Ground Truth ---
# The four essential parts of a body paragraph are the Topic Sentence, Evidence, Analysis, and Transitions.
#
# ================================================================================
#
# --- Question ---
# What is the primary function of a topic sentence in a body paragraph?
#
# --- Agent Response ---
# Oh, great question to start with! Let's break this down together. 🙂
#
# Instead of just giving you the answer straight up, let me ask you this first:
#
# **When you're reading an essay and you hit the start of a new paragraph, what do you think you need to know right away as a reader?**
#
# Think about it from the *reader's perspective* — what would feel confusing or disorienting if it wasn't there?
#
# And here's another angle to consider: **How does a topic sentence relate to the thesis of the whole essay?** Like, if your thesis is the big picture, what role does the topic sentence play?
#
# Take a shot at it — there's no wrong answer here, we're just thinking through it together! 😊
#
# --- Ground Truth ---
# A topic sentence relates the specific topic of the paragraph to the overall thesis and signals to the reader that a new part of the argument is beginning.
#
# ================================================================================
#
# --- Question ---
# According to the text, what constitutes 'evidence' in a body paragraph, and how should it be presented?
#
# --- Agent Response ---
# Oh, great question! Let's break this down together 😊
#
# So the text actually gives us a pretty solid definition to work with. What do you think the text means when it says evidence is **"any detail, fact, quote, or example that illustrates your claim"**?
#
# Like, think about it this way — what kind of paper are *you* working on right now? Because here's the thing the text points out that I find really interesting:
#
# > *"Different types of papers will require different evidence. For example, a scientific research paper will require facts, whereas a personal narrative will probably use details about an event."*
#
# So the **type** of evidence actually shifts depending on your purpose! How do you feel about that idea?
#
# And then there's the *how to present it* piece — the text gives us three guidelines:
#
# - ✅ Choose evidence **appropriate** for your paper
# - ✅ Represent it **honestly**
# - ✅ Introduce it with **enough context**
#
# Here's what I want you to think about — **why do you think context matters so much when introducing evidence?** What might happen if you just dropped a quote or fact in without any setup?
#
# That actually connects really naturally to the next part of body paragraphs — **analysis** — but let's not get ahead of ourselves! 😄
#
# What part of presenting evidence feels most unclear or tricky to you?
#
# --- Ground Truth ---
# Evidence is any detail, fact, quote, or example that illustrates a claim. It should be appropriate for the paper type, represented honestly, and introduced with enough context.
#
# ================================================================================
